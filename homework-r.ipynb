# %% [markdown]
# # DNA 解析
#
# 1116174065：岡　恭平
#
# - 同志社大学データサイエンス：

# %% [markdown]
# ## DNA のCSV 読込

# %%
x <- c(1,2,3,4,5)

# %%
df <- read.csv("sample-1.csv",header=T)

# %%
df
# Out:
#     Description.Sequences..with..E.value.BETTER.than.threshold.
# 1   nucleocapsid protein [Bat coronavirus RaTG13]
# 2   nucleocapsid protein [Bat SARS-like coronavirus]
# 3   nucleocapsid protein [Bat SARS coronavirus Rp1]
# 4   nucleocapsid protein [Bat SARS-like coronavirus]
# 5   nucleocapsid protein [Bat coronavirus]
# 6   nucleocapsid phosphoprotein [Bat SARS coronavirus HKU3-4]
# 7   nucleocapsid phosphoprotein [Bat SARS coronavirus HKU3-7]
# 8   nucleocapsid protein [Bat coronavirus]
# 9   nucleocapsid protein [Bat SARS-like coronavirus]
# 10  nucleocapsid protein [Bat SARS-like coronavirus]
# 11  nucleocapsid protein [Bat SARS-like coronavirus]
# 12  nucleocapsid protein [Bat SARS-like coronavirus]
# 13  nucleocapsid protein [Bat coronavirus Rp/Shaanxi2011]
# 14  nucleocapsid phosphoprotein [Bat SARS coronavirus HKU3-9]
# 15  nucleocapsid protein [Bat SARS-like coronavirus WIV1]
# 16  nucleocapsid phosphoprotein [Bat SARS coronavirus HKU3-12]
# ...

# %%
rowLength = nrow(df)
colLength = ncol(df)
sprintf("列のデータ量:%d",as.integer(rowLength))
sprintf("行のデータ量:%d",as.integer(colLength))
# Out:
# [1] "列のデータ量:884"
# [1] "行のデータ量:8"
